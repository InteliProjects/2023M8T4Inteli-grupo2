# %%
# !pip install .
# Out:
# Processing /mnt/c/Users/maluv/OneDrive/Área de Trabalho/script/ScriptIBGE
#   Preparing metadata (setup.py) ... done
# Using legacy 'setup.py install' for ibge, since package 'wheel' is not installed.
# ...
#   Attempting uninstall: ibge
#     Found existing installation: ibge 0.0.0
#     Uninstalling ibge-0.0.0:
#       Successfully uninstalled ibge-0.0.0
#   Running setup.py install for ibge ... done
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# ============================= test session starts ==============================
# platform linux -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /home/malumaia/.pyenv/versions/3.10.6/envs/seunome/bin/python3.10
# cachedir: .pytest_cache
# rootdir: /mnt/c/Users/maluv/OneDrive/Área de Trabalho/script/ScriptIBGE
# plugins: anyio-3.6.2
# collected 5 items
#
# tests/test_lib.py::test_preprocess_output PASSED                         [ 20%]
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('./csv/dados_sale.csv')
df['saleDate'] = df['saleDate'].str.split('T').str[0]
df
# Out:
#           id            cnpj  idCategory  \
# 0        740  36429502000180          30
# 1        741  44543901000103          22
# 2        742  36091770000134           4
# 3        743  27665906006627          24
# 4        744  39455201000119           2
# ...      ...             ...         ...
# 34336  34975  45408730000164          16
# 34337  34976  23965951000109          26
# 34338  34977  12553309000198          14
# 34339  34978  28452195000120           9
# 34340  34979  46065643000114           4
#
#                                                 category    saleDate  value  \
# 0          {'id': 30, 'name': 'Carne', 'isActive': True}  2023-01-01  181.0
# 1      {'id': 22, 'name': 'Monitor LED', 'isActive': ...  2023-01-01  268.0
# 2           {'id': 4, 'name': 'Arroz', 'isActive': True}  2023-01-01  780.0
# 3          {'id': 24, 'name': 'Livro', 'isActive': True}  2023-01-01  973.0
# 4         {'id': 2, 'name': 'Cerveja', 'isActive': True}  2023-01-01  125.0
# ...

# %%
df.to_csv('./csv_s3/sale_s3.csv', index=False)
