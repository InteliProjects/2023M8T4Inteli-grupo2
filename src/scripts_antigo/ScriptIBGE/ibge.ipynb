# %%
# !pip install .
# Out:
# Processing /mnt/c/Users/maluv/OneDrive/Área de Trabalho/IBGE/pacotePython
#   Preparing metadata (setup.py) ... done
# Using legacy 'setup.py install' for ibge, since package 'wheel' is not installed.
# ...
#   Running setup.py install for ibge ... done
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import ibge.lib as ibge

ibge.preprocess()
# Out:
# Teste IBGE!

# %%
# !pytest tests -v # verbose
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /home/malumaia/.pyenv/versions/3.10.6/envs/seunome/bin/python3.10
# cachedir: .pytest_cache
# rootdir: /mnt/c/Users/maluv/OneDrive/Área de Trabalho/IBGE/pacotePython
# plugins: anyio-3.6.2
# collected 0 items / 1 error
#
# ==================================== ERRORS ====================================
# ______________________ ERROR collecting tests/test_lib.py ______________________
# ImportError while importing test module '/mnt/c/Users/maluv/OneDrive/Área de Trabalho/IBGE/pacotePython/tests/test_lib.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# /home/malumaia/.pyenv/versions/3.10.6/lib/python3.10/importlib/__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# tests/test_lib.py:1: in <module>
#     import ibge.lib as ibge
# ...

# %%
df_gini_geral = ibge.load_data_with_correct_delimiter("./csv/gini_geral.csv")

# %%
# Este código garante que o notebook sempre vai buscar os módulos
# %load_ext autoreload
# %autoreload 2

# %%
df_gini_geral_clean = ibge.clean_data(df_gini_geral)

# %%
df_gini_geral_clean
# Out:
#    Unidade da Federação      2002      2003      2004      2005      2006  \
# 0              Rondônia  0,663476  0,642692  0,655898  0,661969  0,664114
# 1                  Acre  0,733505  0,720977  0,735187  0,733279  0,732895
# 2              Amazonas  0,891846  0,898752  0,907582  0,906511  0,904798
# 3               Roraima  0,754187  0,751256  0,745649  0,746504  0,757404
# 4                  Pará  0,728359  0,725016  0,735970  0,731493  0,737730
# 5                 Amapá  0,802527  0,787800  0,795061  0,782708  0,791405
# 6             Tocantins  0,709031  0,689553  0,692404  0,694704  0,704422
# 7              Maranhão  0,726878  0,726222  0,733106  0,747359  0,754244
# 8                 Piauí  0,769564  0,757789  0,758241  0,767973  0,784127
# 9                 Ceará  0,786772  0,782014  0,792612  0,792617  0,786051
# 10  Rio Grande do Norte  0,798872  0,795312  0,799420  0,803622  0,804342
# 11              Paraíba  0,777902  0,774334  0,770663  0,768940  0,774127
# ...

# %%
gini_geral_s3 = ibge.ajustar_amazon_s3(df_gini_geral_clean, './csv_s3/gini_geral_s3.csv')
# Out:
# /mnt/c/Users/maluv/OneDrive/Área de Trabalho/IBGE/pacotePython/ibge/lib.py:35: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.replace(',', ';') if isinstance(x, str) else x)

# %%
df_gini_industria = ibge.load_data_with_correct_delimiter("./csv/gini_industria.csv")

# %%
df_gini_industria_clean = ibge.clean_data(df_gini_industria)

# %%
df_gini_industria_clean
# Out:
#    Unidade da Federação      2002      2003      2004      2005      2006  \
# 0              Rondônia  0,790535  0,768464  0,774926  0,776917  0,788858
# 1                  Acre  0,839545  0,837409  0,846886  0,868354  0,865321
# 2              Amazonas  0,970171  0,972946  0,973139  0,975159  0,975062
# 3               Roraima  0,859175  0,881024  0,871617  0,860453  0,853717
# 4                  Pará  0,872753  0,873611  0,867314  0,870365  0,865593
# 5                 Amapá  0,827082  0,789789  0,807837  0,802792  0,816648
# 6             Tocantins  0,868443  0,854813  0,856579  0,844340  0,847100
# 7              Maranhão  0,898132  0,902194  0,912669  0,919352  0,905834
# 8                 Piauí  0,935639  0,955225  0,935620  0,951367  0,937481
# 9                 Ceará  0,894928  0,902645  0,904652  0,903154  0,898827
# 10  Rio Grande do Norte  0,894844  0,898712  0,902302  0,904250  0,903543
# 11              Paraíba  0,928720  0,927039  0,914130  0,926048  0,920529
# ...

# %%
gini_industria_s3 = ibge.ajustar_amazon_s3(df_gini_industria_clean, './csv_s3/gini_industria_s3.csv')
# Out:
# /mnt/c/Users/maluv/OneDrive/Área de Trabalho/IBGE/pacotePython/ibge/lib.py:35: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.replace(',', ';') if isinstance(x, str) else x)

# %%
df_pib = ibge.load_data_with_correct_delimiter("./csv/pib.csv")

# %%
df_pib_clean = ibge.clean_data(df_pib)

# %%
df_pib_clean
# Out:
#                        Município      2002      2003      2004      2005  \
# 0     Alta Floresta D'Oeste (RO)    111291    143222    173991    167127
# 1                 Ariquemes (RO)    449593    539636    657193    749021
# 2                    Cabixi (RO)     31768     40985     43392     49130
# 3                    Cacoal (RO)    474443    622437    622415    758960
# 4                Cerejeiras (RO)     79174     99983    121366    129107
# ...                          ...       ...       ...       ...       ...
# 5565             Vianópolis (GO)     86497     96624     95230    104766
# 5566         Vicentinópolis (GO)     66360     89703     97011     73192
# 5567               Vila Boa (GO)     13821     15807     17815     19072
# 5568          Vila Propício (GO)     46056     48835     45258     47147
# 5569               Brasília (DF)  53902200  58456124  67076505  75732681
#
#           2006      2007       2008       2009       2010       2011  \
# ...

# %%
df_pib_s3 = ibge.ajustar_amazon_s3(df_pib_clean, './csv_s3/pib_s3.csv')
# Out:
# /mnt/c/Users/maluv/OneDrive/Área de Trabalho/IBGE/pacotePython/ibge/lib.py:35: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.replace(',', ';') if isinstance(x, str) else x)
